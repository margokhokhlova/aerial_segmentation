# %%
import numpy as np
import torch
from torch.utils.data import DataLoader
import keras.backend as K
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import random
import os
import tensorflow as tf

from dataloaders.osm_dataloader import OSMDataset
from dataloaders.osm_datagenerator import DataGeneratorOSM
from dataloaders.dataset_helper import findallimagesosm

from models.Unet_keras import buildUnet
from dataloaders.img_helper import show_sample, show_sample_gt
# Out:
# Using TensorFlow backend.

# %%
# The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="0"; 
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
#functions for the loss
def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)
def dice_p_bce(in_gt, in_pred):
    return 0.0*binary_crossentropy(in_gt, in_pred) - dice_coef(in_gt, in_pred)
def true_positive_rate(y_true, y_pred):
    return K.sum(K.flatten(y_true)*K.flatten(K.round(y_pred)))/K.sum(y_true)

# %% [markdown]
# # Dataset loading

# %%
 # Datasets
partition, labels = findallimagesosm(folder = '/data/khokhlov/datasets/OSM_processed_margo/')

params = {'dim': (512, 512),
          'batch_size': 10,
          'n_channels_img':3,
          'n_channel_mask':1,
          'shuffle': True}
max_epochs = 100

training_generator = DataGeneratorOSM(partition['train'], labels['train'], **params)
validation_generator = DataGeneratorOSM(partition['validation'], labels['validation'], **params)

(X,y) = training_generator. __getitem__(0)
show_sample(X[0,:].astype(int), np.squeeze(y[0,:]))

(X,y) = validation_generator. __getitem__(0)
show_sample(X[0,:].astype(int), np.squeeze(y[0,:]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Training parameters

# %%
loss_history = []
weight_path = "modelssaved/{}_weights.best.hdf5".format('vgg_unet')
checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, verbose=1, mode='auto',
                                   epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=15)  # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]

# %% [markdown]
# ## Model

# %%
unet_model = buildUnet(X, y) # to initialize the parameters correctly
unet_model.compile(optimizer=Adam(1e-3, decay=1e-6),
                   loss=dice_p_bce,
                   metrics=[dice_coef, 'binary_accuracy', true_positive_rate])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 512, 512, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 512, 512, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 512, 512, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 256, 256, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 256, 256, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 256, 256, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 128, 128, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 128, 128, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 64, 64, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 64, 64, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 32, 32, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# (128, 128) ['MaxPooling2D', 'Conv2D', 'Conv2D', 'Conv2D']
# (32, 32) ['MaxPooling2D', 'Conv2D', 'Conv2D', 'Conv2D']
# (256, 256) ['MaxPooling2D', 'Conv2D', 'Conv2D']
# (16, 16) ['MaxPooling2D']
# (64, 64) ['MaxPooling2D', 'Conv2D', 'Conv2D', 'Conv2D']
# (512, 512) ['Conv2D', 'Conv2D']
# (10, 128, 128, 256) expected (128, 128)
# (10, 32, 32, 512) expected (32, 32)
# (10, 256, 256, 128) expected (256, 256)
# (10, 16, 16, 512) expected (16, 16)
# (10, 64, 64, 512) expected (64, 64)
# (10, 512, 512, 64) expected (512, 512)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# T0_Image (InputLayer)           (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# model_1 (Model)                 [(None, 128, 128, 25 14714688    T0_Image[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 256)  1179904     model_1[1][4]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 295040      model_1[1][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 256)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  295040      activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 73792       model_1[1][2]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 256 0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 512, 32) 18464       model_1[1][5]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 192 0           activation_3[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512, 512, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 96) 165984      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512, 512, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 96) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 128 0           activation_4[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 512, 512, 1)  129         concatenate_3[0][0]
# ==================================================================================================
# Total params: 17,040,001
# Trainable params: 2,324,353
# Non-trainable params: 14,715,648
# __________________________________________________________________________________________________

# %%
loss_history += [unet_model.fit_generator(generator=training_generator, steps_per_epoch=200,
                                          epochs=50,
                                          validation_data=validation_generator, validation_steps=200,
                                          use_multiprocessing=False,
                                          callbacks=callbacks_list)]
# Out:
# Epoch 1/50
# 200/200 [==============================] - 242s 1s/step - loss: -0.6145 - dice_coef: 0.6145 - binary_accuracy: 0.3364 - true_positive_rate: 0.9970 - val_loss: -0.5493 - val_dice_coef: 0.5493 - val_binary_accuracy: 0.2484 - val_true_positive_rate: 1.0000
#
# Epoch 00001: val_loss improved from inf to -0.54933, saving model to modelssaved/vgg_unet_weights.best.hdf5
# Epoch 2/50
# 200/200 [==============================] - 235s 1s/step - loss: -0.6178 - dice_coef: 0.6178 - binary_accuracy: 0.3391 - true_positive_rate: 1.0000 - val_loss: -0.5555 - val_dice_coef: 0.5555 - val_binary_accuracy: 0.2569 - val_true_positive_rate: 1.0000
#
# Epoch 00002: val_loss improved from -0.54933 to -0.55550, saving model to modelssaved/vgg_unet_weights.best.hdf5
# Epoch 3/50
# 200/200 [==============================] - 235s 1s/step - loss: -0.6216 - dice_coef: 0.6216 - binary_accuracy: 0.3438 - true_positive_rate: 1.0000 - val_loss: -0.5585 - val_dice_coef: 0.5585 - val_binary_accuracy: 0.2604 - val_true_positive_rate: 1.0000
#
# Epoch 00003: val_loss improved from -0.55550 to -0.55848, saving model to modelssaved/vgg_unet_weights.best.hdf5
# Epoch 4/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6173 - dice_coef: 0.6173 - binary_accuracy: 0.3385 - true_positive_rate: 1.0000 - val_loss: -0.5463 - val_dice_coef: 0.5463 - val_binary_accuracy: 0.2449 - val_true_positive_rate: 1.0000
#
# Epoch 00004: val_loss did not improve from -0.55848
# Epoch 5/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6195 - dice_coef: 0.6195 - binary_accuracy: 0.3419 - true_positive_rate: 1.0000 - val_loss: -0.5505 - val_dice_coef: 0.5505 - val_binary_accuracy: 0.2502 - val_true_positive_rate: 1.0000
#
# Epoch 00005: val_loss did not improve from -0.55848
# Epoch 6/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6174 - dice_coef: 0.6174 - binary_accuracy: 0.3413 - true_positive_rate: 1.0000 - val_loss: -0.5544 - val_dice_coef: 0.5544 - val_binary_accuracy: 0.2551 - val_true_positive_rate: 1.0000
#
# Epoch 00006: val_loss did not improve from -0.55848
# Epoch 7/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6165 - dice_coef: 0.6165 - binary_accuracy: 0.3384 - true_positive_rate: 1.0000 - val_loss: -0.5471 - val_dice_coef: 0.5471 - val_binary_accuracy: 0.2463 - val_true_positive_rate: 1.0000
#
# Epoch 00007: val_loss did not improve from -0.55848
# Epoch 8/50
# 200/200 [==============================] - 234s 1s/step - loss: -0.6076 - dice_coef: 0.6076 - binary_accuracy: 0.3263 - true_positive_rate: 1.0000 - val_loss: -0.5578 - val_dice_coef: 0.5578 - val_binary_accuracy: 0.2590 - val_true_positive_rate: 1.0000
#
# Epoch 00008: val_loss did not improve from -0.55848
# Epoch 9/50
# 200/200 [==============================] - 234s 1s/step - loss: -0.6108 - dice_coef: 0.6108 - binary_accuracy: 0.3317 - true_positive_rate: 1.0000 - val_loss: -0.5539 - val_dice_coef: 0.5539 - val_binary_accuracy: 0.2552 - val_true_positive_rate: 1.0000
#
# Epoch 00009: val_loss did not improve from -0.55848
# Epoch 10/50
# 200/200 [==============================] - 233s 1s/step - loss: -0.6247 - dice_coef: 0.6247 - binary_accuracy: 0.3482 - true_positive_rate: 1.0000 - val_loss: -0.5509 - val_dice_coef: 0.5509 - val_binary_accuracy: 0.2501 - val_true_positive_rate: 1.0000
#
# Epoch 00010: val_loss did not improve from -0.55848
# Epoch 11/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6303 - dice_coef: 0.6303 - binary_accuracy: 0.3566 - true_positive_rate: 1.0000 - val_loss: -0.5559 - val_dice_coef: 0.5559 - val_binary_accuracy: 0.2571 - val_true_positive_rate: 1.0000
#
# Epoch 00011: val_loss did not improve from -0.55848
# Epoch 12/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6168 - dice_coef: 0.6168 - binary_accuracy: 0.3390 - true_positive_rate: 1.0000 - val_loss: -0.5489 - val_dice_coef: 0.5489 - val_binary_accuracy: 0.2482 - val_true_positive_rate: 1.0000
#
# Epoch 00012: val_loss did not improve from -0.55848
# Epoch 13/50
# 200/200 [==============================] - 235s 1s/step - loss: -0.6060 - dice_coef: 0.6060 - binary_accuracy: 0.3249 - true_positive_rate: 1.0000 - val_loss: -0.5536 - val_dice_coef: 0.5536 - val_binary_accuracy: 0.2542 - val_true_positive_rate: 1.0000
#
# Epoch 00013: val_loss did not improve from -0.55848
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 14/50
# 200/200 [==============================] - 235s 1s/step - loss: -0.6192 - dice_coef: 0.6192 - binary_accuracy: 0.3423 - true_positive_rate: 1.0000 - val_loss: -0.5513 - val_dice_coef: 0.5513 - val_binary_accuracy: 0.2511 - val_true_positive_rate: 1.0000
#
# Epoch 00014: val_loss did not improve from -0.55848
# Epoch 15/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6228 - dice_coef: 0.6228 - binary_accuracy: 0.3446 - true_positive_rate: 1.0000 - val_loss: -0.5607 - val_dice_coef: 0.5607 - val_binary_accuracy: 0.2639 - val_true_positive_rate: 1.0000
#
# Epoch 00015: val_loss improved from -0.55848 to -0.56069, saving model to modelssaved/vgg_unet_weights.best.hdf5
# Epoch 16/50
# 200/200 [==============================] - 235s 1s/step - loss: -0.6163 - dice_coef: 0.6163 - binary_accuracy: 0.3382 - true_positive_rate: 1.0000 - val_loss: -0.5441 - val_dice_coef: 0.5441 - val_binary_accuracy: 0.2414 - val_true_positive_rate: 1.0000
#
# Epoch 00016: val_loss did not improve from -0.56069
# Epoch 17/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6223 - dice_coef: 0.6223 - binary_accuracy: 0.3465 - true_positive_rate: 1.0000 - val_loss: -0.5532 - val_dice_coef: 0.5532 - val_binary_accuracy: 0.2537 - val_true_positive_rate: 1.0000
#
# Epoch 00017: val_loss did not improve from -0.56069
# Epoch 18/50
# 200/200 [==============================] - 236s 1s/step - loss: -0.6156 - dice_coef: 0.6156 - binary_accuracy: 0.3359 - true_positive_rate: 1.0000 - val_loss: -0.5516 - val_dice_coef: 0.5516 - val_binary_accuracy: 0.2516 - val_true_positive_rate: 1.0000
#
# Epoch 00018: val_loss did not improve from -0.56069
# Epoch 19/50
#  74/200 [==========>...................] - ETA: 1:33 - loss: -0.6267 - dice_coef: 0.6267 - binary_accuracy: 0.3525 - true_positive_rate: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-323458723d21> in <module>()
#       4                                           validation_data=validation_generator, validation_steps=200,
#       5                                           use_multiprocessing=False,
# ----> 6                                           callbacks=callbacks_list)]
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/virtenv/refineNet/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
def show_loss(loss_history):
    epich = np.cumsum(np.concatenate(
        [np.linspace(0.5, 1, len(mh.epoch)) for mh in loss_history]))
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(22, 10))
    _ = ax1.plot(epich,
                 np.concatenate([mh.history['loss'] for mh in loss_history]),
                 'b-',
                 epich, np.concatenate(
            [mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')

    _ = ax2.plot(epich, np.concatenate(
        [mh.history['true_positive_rate'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_true_positive_rate'] for mh in loss_history]),
                     'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('True Positive Rate\n(Positive Accuracy)')
    
    _ = ax3.plot(epich, np.concatenate(
        [mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_binary_accuracy'] for mh in loss_history]),
                     'r-')
    ax3.legend(['Training', 'Validation'])
    ax3.set_title('Binary Accuracy (%)')
    
    _ = ax4.plot(epich, np.concatenate(
        [mh.history['dice_coef'] for mh in loss_history]), 'b-',
                     epich, np.concatenate(
            [mh.history['val_dice_coef'] for mh in loss_history]),
                     'r-')
    ax4.legend(['Training', 'Validation'])
    ax4.set_title('DICE')

show_loss(loss_history)

# %%
unet_model.load_weights(weight_path)
unet_model.save('full_seg_model.h5')

# %% [markdown]
# ## Test Data

# %%
# %load_ext autoreload
# %autoreload 2
testing_generator = DataGeneratorOSM(partition['test'], labels['test'], **params)
(X,y) = testing_generator. __getitem__(0)
dm_pred = unet_model.predict([X])
for i in range(dm_pred.shape[0]):
    show_sample_gt(X[i,:].astype(int), np.squeeze(dm_pred[i,:]), np.squeeze(y[i,:]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
